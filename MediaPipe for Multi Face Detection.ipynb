# %%
import cv2
import mediapipe as mp
import tkinter as tk
from tkinter import messagebox

root = tk.Tk()
root.withdraw()

def show_popup():
    messagebox.showwarning("Warning", "Multiple people detected! Please ensure you are alone.")

mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

cap = cv2.VideoCapture(0)

with mp_face_detection.FaceDetection(min_detection_confidence=0.5) as face_detection:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = face_detection.process(frame_rgb)

        face_count = 0
        if results.detections:
            for detection in results.detections:
                face_count += 1
                mp_drawing.draw_detection(frame, detection)

        if face_count >= 2:
            show_popup()

        cv2.imshow('MediaPipe Face Detection', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 37
#      33             show_popup()
#      35         cv2.imshow('MediaPipe Face Detection', frame)
# ---> 37         if cv2.waitKey(1) & 0xFF == ord('q'):
#      38             break
#      40 cap.release()
#
# KeyboardInterrupt:
