# %%
# Step 1: Import Libraries
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.orm import declarative_base, sessionmaker

# Step 2: Set Up SQLite Database
# Create an SQLite database (the database file will be created in the same directory as the notebook)
DATABASE_URL = 'sqlite:///interview_tool.db'
engine = create_engine(DATABASE_URL)

# Step 3: Create a Base Class
Base = declarative_base()

# Step 4: Define a User Model
class User(Base):
    __tablename__ = 'users'
    
    id = Column(Integer, primary_key=True)
    name = Column(String, nullable=False)
    email = Column(String, nullable=False)

# Step 5: Create the Database Tables
Base.metadata.create_all(engine)

# Step 6: Create a Session
Session = sessionmaker(bind=engine)
session = Session()

# Optional: Add a Sample User (to test the setup)
new_user = User(name='John Doe', email='john.doe@example.com')
session.add(new_user)
session.commit()

# Optional: Query the Users Table
users = session.query(User).all()
for user in users:
    print(f'ID: {user.id}, Name: {user.name}, Email: {user.email}')

# Close the session
session.close()
# Out:
# ID: 1, Name: John Doe, Email: john.doe@example.com
# ID: 2, Name: John Doe, Email: john.doe@example.com

# %%
# Step 1: Import the necessary libraries
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.orm import sessionmaker, declarative_base  # Updated import for declarative_base
from sqlalchemy.exc import IntegrityError

# Step 2: Set up the SQLite database and SQLAlchemy
DATABASE_URL = "sqlite:///mock_interview_tool.db"  # Database URL for SQLite
engine = create_engine(DATABASE_URL)
Base = declarative_base()  # No change needed here, as it is imported correctly

# Step 3: Define the Question model
class Question(Base):
    __tablename__ = 'questions'
    
    id = Column(Integer, primary_key=True)
    question_text = Column(String, nullable=False)
    job_role = Column(String, nullable=False)

# Step 4: Create the database tables
Base.metadata.create_all(engine)

# Step 5: Set up a session
Session = sessionmaker(bind=engine)
session = Session()

# Step 6: Function to load questions from CSV into the database
def load_questions_to_db(csv_file):
    df = pd.read_csv(csv_file)
    for _, row in df.iterrows():
        question = Question(question_text=row['Question'], job_role=row['Role'])  # Ensure column names are correct
        session.add(question)
    session.commit()

# Step 7: Load questions from the CSV file
load_questions_to_db('data/Business.csv')  # Ensure this path is correct

# Step 8: Function to retrieve questions based on selected job role
def load_questions(selected_role):
    return session.query(Question).filter(Question.job_role == selected_role).all()

# Example usage
questions = load_questions('Business')  # Replace 'Business' with the desired job role
for question in questions:
    print(f'ID: {question.id}, Question: {question.question_text}, Role: {question.job_role}')

# Step 9: Close the session
session.close()
# Out:
# ID: 1, Question: What is a business model?, Role: Business
# ID: 2, Question: Can you explain what SWOT analysis is?, Role: Business
# ID: 3, Question: What do you understand by the term 'target market'?, Role: Business
# ID: 4, Question: Can you describe the purpose of a marketing plan?, Role: Business
# ID: 5, Question: What is your understanding of a profit and loss statement?, Role: Business
# ID: 6, Question: Can you explain what customer segmentation means?, Role: Business
# ID: 7, Question: What is a value proposition?, Role: Business
# ID: 8, Question: Can you describe the importance of networking in business?, Role: Business
# ID: 9, Question: What do you know about the term 'market research'?, Role: Business
# ID: 10, Question: Can you explain what a competitive advantage is?, Role: Business
# ID: 11, Question: What is the role of a business analyst?, Role: Business
# ID: 12, Question: Can you define what customer relationship management (CRM) is?, Role: Business
# ID: 13, Question: What are the basic principles of supply chain management?, Role: Business
# ID: 14, Question: Can you explain the difference between B2B and B2C?, Role: Business
# ID: 15, Question: What is your experience with budgeting?, Role: Business
# ID: 16, Question: Can you describe what corporate social responsibility (CSR) means?, Role: Business
# ID: 17, Question: What do you understand by the term 'value chain'?, Role: Business
# ID: 18, Question: Can you explain what a stakeholder is?, Role: Business
# ID: 19, Question: What is your understanding of key performance indicators (KPIs)?, Role: Business
# ID: 20, Question: Can you describe what an elevator pitch is?, Role: Business
# ID: 21, Question: What is the role of leadership in a business?, Role: Business
# ID: 22, Question: Can you explain what market positioning means?, Role: Business
# ID: 23, Question: What do you understand by the term 'brand equity'?, Role: Business
# ID: 24, Question: Can you describe the purpose of a business plan?, Role: Business
# ID: 25, Question: What is your experience with sales techniques?, Role: Business
# ID: 26, Question: Can you explain the difference between fixed and variable costs?, Role: Business
# ID: 27, Question: What do you know about employee engagement?, Role: Business
# ID: 28, Question: Can you describe what a merger and acquisition (M&A) is?, Role: Business
# ID: 29, Question: What is your understanding of business ethics?, Role: Business
# ID: 30, Question: Can you explain the concept of lean management?, Role: Business
# ID: 31, Question: What do you understand by the term 'cash flow'?, Role: Business
# ID: 32, Question: Can you describe what a franchise is?, Role: Business
# ID: 33, Question: What is the importance of customer feedback?, Role: Business
# ID: 34, Question: Can you explain what a target audience is?, Role: Business
# ID: 35, Question: What do you know about the concept of diversification?, Role: Business
# ID: 36, Question: Can you describe what strategic planning is?, Role: Business
# ID: 37, Question: What is your experience with project management?, Role: Business
# ID: 38, Question: Can you explain what a business continuity plan (BCP) is?, Role: Business
# ID: 39, Question: What are the different types of business structures?, Role: Business
# ID: 40, Question: Can you explain what corporate governance is?, Role: Business
# ID: 41, Question: What is your understanding of the sales funnel?, Role: Business
# ID: 42, Question: Can you describe what e-commerce is?, Role: Business
# ID: 43, Question: What do you understand by the term 'customer journey'?, Role: Business
# ID: 44, Question: Can you explain the concept of market share?, Role: Business
# ID: 45, Question: What is your experience with financial analysis?, Role: Business
# ID: 46, Question: Can you describe what a marketing strategy is?, Role: Business
# ID: 47, Question: What do you understand by the term 'operational efficiency'?, Role: Business
# ID: 48, Question: Can you explain what a business ecosystem is?, Role: Business
# ID: 49, Question: What is your understanding of the term 'workplace culture'?, Role: Business
# ID: 50, Question: Can you describe what innovation means in business?, Role: Business
# ID: 51, Question: Can you explain the concept of strategic alliances?, Role: Business
# ID: 52, Question: What are some common business growth strategies?, Role: Business
# ID: 53, Question: Can you describe the role of a business consultant?, Role: Business
# ID: 54, Question: What is your experience with conducting market analysis?, Role: Business
# ID: 55, Question: Can you explain the importance of brand management?, Role: Business
# ID: 56, Question: What are some effective negotiation techniques?, Role: Business
# ID: 57, Question: Can you describe what a business incubator is?, Role: Business
# ID: 58, Question: What is your understanding of corporate finance?, Role: Business
# ID: 59, Question: Can you explain how to create a marketing budget?, Role: Business
# ID: 60, Question: What are the benefits of using data analytics in business?, Role: Business
# ID: 61, Question: Can you describe the impact of digital transformation on businesses?, Role: Business
# ID: 62, Question: What is your experience with international business practices?, Role: Business
# ID: 63, Question: Can you explain the concept of corporate entrepreneurship?, Role: Business
# ID: 64, Question: What are some key components of a successful sales strategy?, Role: Business
# ID: 65, Question: Can you describe the importance of customer loyalty?, Role: Business
# ID: 66, Question: What is your understanding of change management?, Role: Business
# ID: 67, Question: Can you explain how to conduct a competitor analysis?, Role: Business
# ID: 68, Question: What are the different types of pricing strategies?, Role: Business
# ID: 69, Question: Can you describe what business forecasting is?, Role: Business
# ID: 70, Question: What is your experience with supply chain optimization?, Role: Business
# ID: 71, Question: Can you explain the role of a marketing manager?, Role: Business
# ID: 72, Question: What are some common risks in business operations?, Role: Business
# ID: 73, Question: Can you describe the importance of employee training?, Role: Business
# ID: 74, Question: What is your understanding of product lifecycle management?, Role: Business
# ID: 75, Question: Can you explain what a balanced scorecard is?, Role: Business
# ID: 76, Question: What are some challenges in managing remote teams?, Role: Business
# ID: 77, Question: Can you describe what ethical leadership entails?, Role: Business
# ID: 78, Question: What is your experience with mergers and acquisitions?, Role: Business
# ID: 79, Question: Can you explain the concept of customer lifetime value?, Role: Business
# ID: 80, Question: What are some effective techniques for conflict resolution?, Role: Business
# ID: 81, Question: Can you describe what social media marketing involves?, Role: Business
# ID: 82, Question: What is your understanding of organizational behavior?, Role: Business
# ID: 83, Question: Can you explain the concept of product differentiation?, Role: Business
# ID: 84, Question: What are some best practices for managing stakeholder relationships?, Role: Business
# ID: 85, Question: Can you describe the importance of corporate branding?, Role: Business
# ID: 86, Question: What is your experience with business risk management?, Role: Business
# ID: 87, Question: Can you explain the concept of employee empowerment?, Role: Business
# ID: 88, Question: What are some common tools for project management?, Role: Business
# ID: 89, Question: Can you describe the role of financial statements in business?, Role: Business
# ID: 90, Question: What is your understanding of operational strategy?, Role: Business
# ID: 91, Question: Can you explain how to conduct a feasibility study?, Role: Business
# ID: 92, Question: What are some effective methods for performance evaluation?, Role: Business
# ID: 93, Question: Can you describe what a business ethics program involves?, Role: Business
# ID: 94, Question: What is your experience with crisis management?, Role: Business
# ID: 95, Question: Can you explain the role of business intelligence (BI)?, Role: Business
# ID: 96, Question: What are the key components of a successful marketing campaign?, Role: Business
# ID: 97, Question: Can you describe the concept of brand positioning?, Role: Business
# ID: 98, Question: What is your understanding of supply chain sustainability?, Role: Business
# ID: 99, Question: Can you explain how to manage a product recall?, Role: Business
# ID: 100, Question: What are some trends you see shaping the future of business?, Role: Business
# ID: 101, Question: Can you describe the challenges of global supply chains?, Role: Business
# ID: 102, Question: What is your experience with strategic decision-making?, Role: Business
# ID: 103, Question: Can you explain the role of artificial intelligence in business?, Role: Business
# ID: 104, Question: What are some strategies for driving innovation in an organization?, Role: Business
# ID: 105, Question: Can you describe the importance of change leadership?, Role: Business
# ID: 106, Question: What is your understanding of the role of data analytics in business strategy?, Role: Business
# ID: 107, Question: Can you explain the concept of strategic risk management?, Role: Business
# ID: 108, Question: What are the implications of blockchain technology for businesses?, Role: Business
# ID: 109, Question: Can you describe how to build a resilient organizational culture?, Role: Business
# ID: 110, Question: What is your experience with stakeholder engagement strategies?, Role: Business
# ID: 111, Question: Can you explain the importance of sustainability in business practices?, Role: Business
# ID: 112, Question: What are the challenges of managing a diverse workforce?, Role: Business
# ID: 113, Question: Can you describe how to implement a successful change initiative?, Role: Business
# ID: 114, Question: What is your understanding of corporate governance best practices?, Role: Business
# ID: 115, Question: Can you explain the role of digital marketing in modern business?, Role: Business
# ID: 116, Question: What are some advanced techniques for customer retention?, Role: Business
# ID: 117, Question: Can you describe the process of developing a comprehensive business strategy?, Role: Business
# ID: 118, Question: What is your experience with performance metrics in evaluating business success?, Role: Business
# ID: 119, Question: Can you explain how to leverage social media for brand growth?, Role: Business
# ID: 120, Question: What are the key factors in building a successful startup?, Role: Business
# ID: 121, Question: Can you describe the impact of globalization on business?, Role: Business
# ID: 122, Question: What is your understanding of market entry strategies?, Role: Business
# ID: 123, Question: Can you explain the concept of competitive intelligence?, Role: Business
# ID: 124, Question: What are the best practices for negotiating business deals?, Role: Business
# ID: 125, Question: Can you describe how to create a culture of innovation?, Role: Business
# ID: 126, Question: What is your experience with talent acquisition strategies?, Role: Business
# ID: 127, Question: Can you explain the role of corporate culture in employee performance?, Role: Business
# ID: 128, Question: What are some advanced approaches to change management?, Role: Business
# ID: 129, Question: Can you describe the importance of ethical decision-making in business?, Role: Business
# ID: 130, Question: What is your understanding of the impact of technology on business models?, Role: Business
# ID: 131, Question: Can you explain the concept of data-driven decision-making?, Role: Business
# ID: 132, Question: What are the challenges of leading a remote organization?, Role: Business
# ID: 133, Question: Can you describe how to measure return on investment (ROI) in marketing?, Role: Business
# ID: 134, Question: What is your experience with business transformation initiatives?, Role: Business
# ID: 135, Question: Can you explain the role of corporate strategy in long-term success?, Role: Business
# ID: 136, Question: What are the implications of technological disruption for established businesses?, Role: Business
# ID: 137, Question: Can you describe how to conduct an organizational assessment?, Role: Business
# ID: 138, Question: What is your understanding of the factors influencing consumer behavior?, Role: Business
# ID: 139, Question: Can you explain the importance of employee engagement in achieving business goals?, Role: Business
# ID: 140, Question: What are some strategies for enhancing brand loyalty?, Role: Business
# ID: 141, Question: Can you describe the process of developing a corporate social responsibility (CSR) program?, Role: Business
# ID: 142, Question: What is your experience with aligning business and IT strategies?, Role: Business
# ID: 143, Question: Can you explain the role of customer experience management (CEM) in business?, Role: Business
# ID: 144, Question: What are the key elements of successful digital transformation?, Role: Business
# ID: 145, Question: Can you describe how to assess business performance using analytics?, Role: Business
# ID: 146, Question: What is your understanding of market disruption and innovation?, Role: Business
# ID: 147, Question: Can you explain the importance of cross-functional collaboration in business?, Role: Business
# ID: 148, Question: What are some advanced techniques for effective project management?, Role: Business
# ID: 149, Question: Can you describe how to implement a customer-centric business model?, Role: Business
# ID: 150, Question: What is a business model?, Role: Business
# ID: 151, Question: Can you explain what SWOT analysis is?, Role: Business
# ID: 152, Question: What do you understand by the term 'target market'?, Role: Business
# ID: 153, Question: Can you describe the purpose of a marketing plan?, Role: Business
# ID: 154, Question: What is your understanding of a profit and loss statement?, Role: Business
# ID: 155, Question: Can you explain what customer segmentation means?, Role: Business
# ID: 156, Question: What is a value proposition?, Role: Business
# ID: 157, Question: Can you describe the importance of networking in business?, Role: Business
# ID: 158, Question: What do you know about the term 'market research'?, Role: Business
# ID: 159, Question: Can you explain what a competitive advantage is?, Role: Business
# ID: 160, Question: What is the role of a business analyst?, Role: Business
# ID: 161, Question: Can you define what customer relationship management (CRM) is?, Role: Business
# ID: 162, Question: What are the basic principles of supply chain management?, Role: Business
# ID: 163, Question: Can you explain the difference between B2B and B2C?, Role: Business
# ID: 164, Question: What is your experience with budgeting?, Role: Business
# ID: 165, Question: Can you describe what corporate social responsibility (CSR) means?, Role: Business
# ID: 166, Question: What do you understand by the term 'value chain'?, Role: Business
# ID: 167, Question: Can you explain what a stakeholder is?, Role: Business
# ID: 168, Question: What is your understanding of key performance indicators (KPIs)?, Role: Business
# ID: 169, Question: Can you describe what an elevator pitch is?, Role: Business
# ID: 170, Question: What is the role of leadership in a business?, Role: Business
# ID: 171, Question: Can you explain what market positioning means?, Role: Business
# ID: 172, Question: What do you understand by the term 'brand equity'?, Role: Business
# ID: 173, Question: Can you describe the purpose of a business plan?, Role: Business
# ID: 174, Question: What is your experience with sales techniques?, Role: Business
# ID: 175, Question: Can you explain the difference between fixed and variable costs?, Role: Business
# ID: 176, Question: What do you know about employee engagement?, Role: Business
# ID: 177, Question: Can you describe what a merger and acquisition (M&A) is?, Role: Business
# ID: 178, Question: What is your understanding of business ethics?, Role: Business
# ID: 179, Question: Can you explain the concept of lean management?, Role: Business
# ID: 180, Question: What do you understand by the term 'cash flow'?, Role: Business
# ID: 181, Question: Can you describe what a franchise is?, Role: Business
# ID: 182, Question: What is the importance of customer feedback?, Role: Business
# ID: 183, Question: Can you explain what a target audience is?, Role: Business
# ID: 184, Question: What do you know about the concept of diversification?, Role: Business
# ID: 185, Question: Can you describe what strategic planning is?, Role: Business
# ID: 186, Question: What is your experience with project management?, Role: Business
# ID: 187, Question: Can you explain what a business continuity plan (BCP) is?, Role: Business
# ID: 188, Question: What are the different types of business structures?, Role: Business
# ID: 189, Question: Can you explain what corporate governance is?, Role: Business
# ID: 190, Question: What is your understanding of the sales funnel?, Role: Business
# ID: 191, Question: Can you describe what e-commerce is?, Role: Business
# ID: 192, Question: What do you understand by the term 'customer journey'?, Role: Business
# ID: 193, Question: Can you explain the concept of market share?, Role: Business
# ID: 194, Question: What is your experience with financial analysis?, Role: Business
# ID: 195, Question: Can you describe what a marketing strategy is?, Role: Business
# ID: 196, Question: What do you understand by the term 'operational efficiency'?, Role: Business
# ID: 197, Question: Can you explain what a business ecosystem is?, Role: Business
# ID: 198, Question: What is your understanding of the term 'workplace culture'?, Role: Business
# ID: 199, Question: Can you describe what innovation means in business?, Role: Business
# ID: 200, Question: Can you explain the concept of strategic alliances?, Role: Business
# ID: 201, Question: What are some common business growth strategies?, Role: Business
# ID: 202, Question: Can you describe the role of a business consultant?, Role: Business
# ID: 203, Question: What is your experience with conducting market analysis?, Role: Business
# ID: 204, Question: Can you explain the importance of brand management?, Role: Business
# ID: 205, Question: What are some effective negotiation techniques?, Role: Business
# ID: 206, Question: Can you describe what a business incubator is?, Role: Business
# ID: 207, Question: What is your understanding of corporate finance?, Role: Business
# ID: 208, Question: Can you explain how to create a marketing budget?, Role: Business
# ID: 209, Question: What are the benefits of using data analytics in business?, Role: Business
# ID: 210, Question: Can you describe the impact of digital transformation on businesses?, Role: Business
# ID: 211, Question: What is your experience with international business practices?, Role: Business
# ID: 212, Question: Can you explain the concept of corporate entrepreneurship?, Role: Business
# ID: 213, Question: What are some key components of a successful sales strategy?, Role: Business
# ID: 214, Question: Can you describe the importance of customer loyalty?, Role: Business
# ID: 215, Question: What is your understanding of change management?, Role: Business
# ID: 216, Question: Can you explain how to conduct a competitor analysis?, Role: Business
# ID: 217, Question: What are the different types of pricing strategies?, Role: Business
# ID: 218, Question: Can you describe what business forecasting is?, Role: Business
# ID: 219, Question: What is your experience with supply chain optimization?, Role: Business
# ID: 220, Question: Can you explain the role of a marketing manager?, Role: Business
# ID: 221, Question: What are some common risks in business operations?, Role: Business
# ID: 222, Question: Can you describe the importance of employee training?, Role: Business
# ID: 223, Question: What is your understanding of product lifecycle management?, Role: Business
# ID: 224, Question: Can you explain what a balanced scorecard is?, Role: Business
# ID: 225, Question: What are some challenges in managing remote teams?, Role: Business
# ID: 226, Question: Can you describe what ethical leadership entails?, Role: Business
# ID: 227, Question: What is your experience with mergers and acquisitions?, Role: Business
# ID: 228, Question: Can you explain the concept of customer lifetime value?, Role: Business
# ID: 229, Question: What are some effective techniques for conflict resolution?, Role: Business
# ID: 230, Question: Can you describe what social media marketing involves?, Role: Business
# ID: 231, Question: What is your understanding of organizational behavior?, Role: Business
# ID: 232, Question: Can you explain the concept of product differentiation?, Role: Business
# ID: 233, Question: What are some best practices for managing stakeholder relationships?, Role: Business
# ID: 234, Question: Can you describe the importance of corporate branding?, Role: Business
# ID: 235, Question: What is your experience with business risk management?, Role: Business
# ID: 236, Question: Can you explain the concept of employee empowerment?, Role: Business
# ID: 237, Question: What are some common tools for project management?, Role: Business
# ID: 238, Question: Can you describe the role of financial statements in business?, Role: Business
# ID: 239, Question: What is your understanding of operational strategy?, Role: Business
# ID: 240, Question: Can you explain how to conduct a feasibility study?, Role: Business
# ID: 241, Question: What are some effective methods for performance evaluation?, Role: Business
# ID: 242, Question: Can you describe what a business ethics program involves?, Role: Business
# ID: 243, Question: What is your experience with crisis management?, Role: Business
# ID: 244, Question: Can you explain the role of business intelligence (BI)?, Role: Business
# ID: 245, Question: What are the key components of a successful marketing campaign?, Role: Business
# ID: 246, Question: Can you describe the concept of brand positioning?, Role: Business
# ID: 247, Question: What is your understanding of supply chain sustainability?, Role: Business
# ID: 248, Question: Can you explain how to manage a product recall?, Role: Business
# ID: 249, Question: What are some trends you see shaping the future of business?, Role: Business
# ID: 250, Question: Can you describe the challenges of global supply chains?, Role: Business
# ID: 251, Question: What is your experience with strategic decision-making?, Role: Business
# ID: 252, Question: Can you explain the role of artificial intelligence in business?, Role: Business
# ID: 253, Question: What are some strategies for driving innovation in an organization?, Role: Business
# ID: 254, Question: Can you describe the importance of change leadership?, Role: Business
# ID: 255, Question: What is your understanding of the role of data analytics in business strategy?, Role: Business
# ID: 256, Question: Can you explain the concept of strategic risk management?, Role: Business
# ID: 257, Question: What are the implications of blockchain technology for businesses?, Role: Business
# ID: 258, Question: Can you describe how to build a resilient organizational culture?, Role: Business
# ID: 259, Question: What is your experience with stakeholder engagement strategies?, Role: Business
# ID: 260, Question: Can you explain the importance of sustainability in business practices?, Role: Business
# ID: 261, Question: What are the challenges of managing a diverse workforce?, Role: Business
# ID: 262, Question: Can you describe how to implement a successful change initiative?, Role: Business
# ID: 263, Question: What is your understanding of corporate governance best practices?, Role: Business
# ID: 264, Question: Can you explain the role of digital marketing in modern business?, Role: Business
# ID: 265, Question: What are some advanced techniques for customer retention?, Role: Business
# ID: 266, Question: Can you describe the process of developing a comprehensive business strategy?, Role: Business
# ID: 267, Question: What is your experience with performance metrics in evaluating business success?, Role: Business
# ID: 268, Question: Can you explain how to leverage social media for brand growth?, Role: Business
# ID: 269, Question: What are the key factors in building a successful startup?, Role: Business
# ID: 270, Question: Can you describe the impact of globalization on business?, Role: Business
# ID: 271, Question: What is your understanding of market entry strategies?, Role: Business
# ID: 272, Question: Can you explain the concept of competitive intelligence?, Role: Business
# ID: 273, Question: What are the best practices for negotiating business deals?, Role: Business
# ID: 274, Question: Can you describe how to create a culture of innovation?, Role: Business
# ID: 275, Question: What is your experience with talent acquisition strategies?, Role: Business
# ID: 276, Question: Can you explain the role of corporate culture in employee performance?, Role: Business
# ID: 277, Question: What are some advanced approaches to change management?, Role: Business
# ID: 278, Question: Can you describe the importance of ethical decision-making in business?, Role: Business
# ID: 279, Question: What is your understanding of the impact of technology on business models?, Role: Business
# ID: 280, Question: Can you explain the concept of data-driven decision-making?, Role: Business
# ID: 281, Question: What are the challenges of leading a remote organization?, Role: Business
# ID: 282, Question: Can you describe how to measure return on investment (ROI) in marketing?, Role: Business
# ID: 283, Question: What is your experience with business transformation initiatives?, Role: Business
# ID: 284, Question: Can you explain the role of corporate strategy in long-term success?, Role: Business
# ID: 285, Question: What are the implications of technological disruption for established businesses?, Role: Business
# ID: 286, Question: Can you describe how to conduct an organizational assessment?, Role: Business
# ID: 287, Question: What is your understanding of the factors influencing consumer behavior?, Role: Business
# ID: 288, Question: Can you explain the importance of employee engagement in achieving business goals?, Role: Business
# ID: 289, Question: What are some strategies for enhancing brand loyalty?, Role: Business
# ID: 290, Question: Can you describe the process of developing a corporate social responsibility (CSR) program?, Role: Business
# ID: 291, Question: What is your experience with aligning business and IT strategies?, Role: Business
# ID: 292, Question: Can you explain the role of customer experience management (CEM) in business?, Role: Business
# ID: 293, Question: What are the key elements of successful digital transformation?, Role: Business
# ID: 294, Question: Can you describe how to assess business performance using analytics?, Role: Business
# ID: 295, Question: What is your understanding of market disruption and innovation?, Role: Business
# ID: 296, Question: Can you explain the importance of cross-functional collaboration in business?, Role: Business
# ID: 297, Question: What are some advanced techniques for effective project management?, Role: Business
# ID: 298, Question: Can you describe how to implement a customer-centric business model?, Role: Business

# %%
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.orm import declarative_base, sessionmaker

# Step 1: Connect to SQLite database
engine = create_engine('sqlite:///mydatabase.db', echo=True)

# Step 2: Create a declarative base
Base = declarative_base()

# Step 3: Define the User class with the role column
class User(Base):
    __tablename__ = 'users'
    
    id = Column(Integer, primary_key=True)
    name = Column(String)
    email = Column(String)
    role = Column(String)  # Ensure role column is defined here

# Step 4: Drop the table (to avoid conflicts with previous schema)
User.__table__.drop(engine, checkfirst=True)  # checkfirst=True avoids error if table doesn't exist

# Step 5: Create the users table with the correct schema
Base.metadata.create_all(engine)

# Step 6: Create a session
Session = sessionmaker(bind=engine)
session = Session()

# Step 7: Add a new user
new_user = User(name="Jane Smith", email="jane.smith@example.com", role="Business Analyst")
session.add(new_user)
session.commit()

# Step 8: Query and print users to verify the insertion
users = session.query(User).all()
for user in users:
    print(f"ID: {user.id}, Name: {user.name}, Email: {user.email}, Role: {user.role}")
# Out:
# 2024-10-12 15:21:14,824 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-12 15:21:14,829 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("users")
# 2024-10-12 15:21:14,832 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-12 15:21:14,834 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("users")
# 2024-10-12 15:21:14,836 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-12 15:21:14,838 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-12 15:21:14,840 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-12 15:21:14,843 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("users")
# 2024-10-12 15:21:14,846 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-12 15:21:14,848 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("users")
# 2024-10-12 15:21:14,850 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-10-12 15:21:14,861 INFO sqlalchemy.engine.Engine
# CREATE TABLE users (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	email VARCHAR,
# 	role VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# 2024-10-12 15:21:14,862 INFO sqlalchemy.engine.Engine [no key 0.00186s] ()
# 2024-10-12 15:21:14,881 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-12 15:21:14,890 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-12 15:21:14,908 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email, role) VALUES (?, ?, ?)
# 2024-10-12 15:21:14,910 INFO sqlalchemy.engine.Engine [generated in 0.01165s] ('Jane Smith', 'jane.smith@example.com', 'Business Analyst')
# 2024-10-12 15:21:14,916 INFO sqlalchemy.engine.Engine COMMIT
# 2024-10-12 15:21:14,923 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-12 15:21:14,930 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email, users.role AS users_role
# FROM users
# 2024-10-12 15:21:14,932 INFO sqlalchemy.engine.Engine [generated in 0.00207s] ()
# ID: 1, Name: Jane Smith, Email: jane.smith@example.com, Role: Business Analyst

# %%
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.orm import declarative_base, sessionmaker

# Step 1: Connect to SQLite database
engine = create_engine('sqlite:///mydatabase.db', echo=False)

# Step 2: Create a declarative base
Base = declarative_base()

# Step 3: Define the User class
class User(Base):
    __tablename__ = 'users'
    
    id = Column(Integer, primary_key=True)
    name = Column(String)
    email = Column(String)
    role = Column(String)

# Step 4: Create the users table
Base.metadata.create_all(engine)

# Step 5: Create a session
Session = sessionmaker(bind=engine)
session = Session()

# Step 6: Add 5 new users
users_data = [
    User(name="Jane Smith", email="jane.smith@example.com", role="Business Analyst"),
    User(name="John Doe", email="john.doe@example.com", role="Software Engineer"),
    User(name="Mary Johnson", email="mary.johnson@example.com", role="Data Scientist"),
    User(name="Robert Brown", email="robert.brown@example.com", role="Project Manager"),
    User(name="Emily Davis", email="emily.davis@example.com", role="UX Designer")
]

session.add_all(users_data)
session.commit()

# Step 7: Query and print users to verify the insertion
users = session.query(User).all()
for user in users:
    print(f"ID: {user.id}, Name: {user.name}, Email: {user.email}, Role: {user.role}")
# Out:
# ID: 1, Name: Jane Smith, Email: jane.smith@example.com, Role: Business Analyst
# ID: 2, Name: Jane Smith, Email: jane.smith@example.com, Role: Business Analyst
# ID: 3, Name: John Doe, Email: john.doe@example.com, Role: Software Engineer
# ID: 4, Name: Mary Johnson, Email: mary.johnson@example.com, Role: Data Scientist
# ID: 5, Name: Robert Brown, Email: robert.brown@example.com, Role: Project Manager
# ID: 6, Name: Emily Davis, Email: emily.davis@example.com, Role: UX Designer

# %%
# Step 8: Update the first row (id = 1) with new user details
user_to_update = session.query(User).filter_by(id=1).first()

if user_to_update:
    user_to_update.name = "Alice Walker"
    user_to_update.email = "alice.walker@example.com"
    user_to_update.role = "Product Manager"
    
    session.commit()

# Step 9: Query and print all users again to verify the update
users = session.query(User).all()
for user in users:
    print(f"ID: {user.id}, Name: {user.name}, Email: {user.email}, Role: {user.role}")
# Out:
# ID: 1, Name: Alice Walker, Email: alice.walker@example.com, Role: Product Manager
# ID: 2, Name: Jane Smith, Email: jane.smith@example.com, Role: Business Analyst
# ID: 3, Name: John Doe, Email: john.doe@example.com, Role: Software Engineer
# ID: 4, Name: Mary Johnson, Email: mary.johnson@example.com, Role: Data Scientist
# ID: 5, Name: Robert Brown, Email: robert.brown@example.com, Role: Project Manager
# ID: 6, Name: Emily Davis, Email: emily.davis@example.com, Role: UX Designer

# %%
from sqlalchemy import create_engine, inspect

# Replace 'sqlite:///your_database.db' with your actual database URI
engine = create_engine('sqlite:///interview_tool.db')
inspector = inspect(engine)

# Print the tables and their columns
for table_name in inspector.get_table_names():
    print(f"Table: {table_name}, Columns: {inspector.get_columns(table_name)}")
# Out:
# Table: questions, Columns: [{'name': 'id', 'type': INTEGER(), 'nullable': False, 'default': None, 'primary_key': 1}, {'name': 'question_text', 'type': VARCHAR(), 'nullable': False, 'default': None, 'primary_key': 0}, {'name': 'job_role', 'type': VARCHAR(), 'nullable': False, 'default': None, 'primary_key': 0}]
# Table: users, Columns: [{'name': 'id', 'type': INTEGER(), 'nullable': False, 'default': None, 'primary_key': 1}, {'name': 'name', 'type': VARCHAR(), 'nullable': False, 'default': None, 'primary_key': 0}, {'name': 'email', 'type': VARCHAR(), 'nullable': False, 'default': None, 'primary_key': 0}]

# %%
pip install prettytable
# Out:
# Collecting prettytableNote: you may need to restart the kernel to use updated packages.
#
#   Downloading prettytable-3.11.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: wcwidth in c:\users\16479\anaconda3\lib\site-packages (from prettytable) (0.2.5)
# Downloading prettytable-3.11.0-py3-none-any.whl (28 kB)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.11.0

# %%
from sqlalchemy import create_engine, inspect
from prettytable import PrettyTable

# Replace 'sqlite:///your_database.db' with your actual database URI
engine = create_engine('sqlite:///interview_tool.db')
inspector = inspect(engine)

# Function to create a PrettyTable for a given table
def display_table_structure(table_name):
    table = PrettyTable()
    table.field_names = ["Column Name", "Type", "Nullable"]
    
    # Fetch columns for the specified table
    columns = inspector.get_columns(table_name)
    for column in columns:
        table.add_row([column['name'], column['type'], column['nullable']])
    
    return table

# Display the structure for the 'users' table
users_table = display_table_structure('users')
print("Users Table Structure:")
print(users_table)

# Display the structure for the 'questions' table
questions_table = display_table_structure('questions')
print("\nQuestions Table Structure:")
print(questions_table)
# Out:
# Users Table Structure:
# +-------------+---------+----------+
# | Column Name |   Type  | Nullable |
# +-------------+---------+----------+
# |      id     | INTEGER |  False   |
# |     name    | VARCHAR |  False   |
# |    email    | VARCHAR |  False   |
# +-------------+---------+----------+
#
# Questions Table Structure:
# +---------------+---------+----------+
# |  Column Name  |   Type  | Nullable |
# +---------------+---------+----------+
# |       id      | INTEGER |  False   |
# | question_text | VARCHAR |  False   |
# |    job_role   | VARCHAR |  False   |
# +---------------+---------+----------+
