# %%
# !pip install gTTS
# Out:
# ...
#   Using cached gTTS-2.5.3-py3-none-any.whl.metadata (4.1 kB)
# ...
# Using cached gTTS-2.5.3-py3-none-any.whl (29 kB)
# ...

# %%
from gtts import gTTS
import os

# Function to convert text to audio
def text_to_audio(text, filename):
    tts = gTTS(text=text, lang='en', slow=False)  # Set slow=True for slower narration
    tts.save(filename)
    os.system(f"start {filename}")  # For Windows. Use 'afplay' for Mac or 'mpg321' for Linux

# Example usage
interview_question = "What are your greatest ?"
text_to_audio(interview_question, "question1.mp3")

# %%
from IPython.display import Audio

# Display the audio file in Jupyter
display(Audio("question1.mp3"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
