# %%
# Import necessary libraries
import speech_recognition as sr
import language_tool_python

# Initialize recognizer and grammar tool
recognizer = sr.Recognizer()
tool = language_tool_python.LanguageTool('en-US')

def process_audio(audio_file):
    # Convert audio to text
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)
        text = recognizer.recognize_google(audio_data)
    
    # Check grammar
    matches = tool.check(text)
    
    return text, matches

# Example usage
audio_path = "path_to_your_audio_file.wav"  # Replace with your audio file path
transcribed_text, grammar_issues = process_audio(audio_path)

# Output results
print("Transcribed Text:")
print(transcribed_text)
print("\nGrammar Issues:")
for issue in grammar_issues:
    print(f"Issue: {issue.message}, Context: {issue.context}, Correction: {issue.replacements}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Import necessary libraries
#       2 import speech_recognition as sr
# ----> 3 import language_tool_python
#       5 # Initialize recognizer and grammar tool
#       6 recognizer = sr.Recognizer()
#
# ModuleNotFoundError: No module named 'language_tool_python'

# %%
# !pip install language-tool-python

# %%
# Import necessary libraries
import speech_recognition as sr
import language_tool_python
from pydub import AudioSegment

# Initialize recognizer and grammar tool
recognizer = sr.Recognizer()
tool = language_tool_python.LanguageTool('en-US')

def mp3_to_wav(mp3_file):
    # Convert MP3 to WAV
    wav_file = mp3_file.replace('.mp3', '.wav')
    audio = AudioSegment.from_mp3(mp3_file)
    audio.export(wav_file, format='wav')
    return wav_file

def process_audio(audio_file):
    # Convert audio to text
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)
        text = recognizer.recognize_google(audio_data)
    
    # Check grammar
    matches = tool.check(text)
    
    return text, matches

# Example usage
mp3_path = "question.mp3"  # Replace with your MP3 file path
wav_path = mp3_to_wav(mp3_path)
transcribed_text, grammar_issues = process_audio(wav_path)

# Output results
print("Transcribed Text:")
print(transcribed_text)
print("\nGrammar Issues:")
for issue in grammar_issues:
    print(f"Issue: {issue.message}, Context: {issue.context}, Correction: {issue.replacements}")
# Out:
# C:\Users\jugra\anaconda3\Lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 8
#       6 # Initialize recognizer and grammar tool
#       7 recognizer = sr.Recognizer()
# ----> 8 tool = language_tool_python.LanguageTool('en-US')
#      10 def mp3_to_wav(mp3_file):
#      11     # Convert MP3 to WAV
#      12     wav_file = mp3_file.replace('.mp3', '.wav')
#
# File ~\anaconda3\Lib\site-packages\language_tool_python\server.py:70, in LanguageTool.__init__(self, language, motherTongue, remote_server, newSpellings, new_spellings_persist, host, config, language_tool_download_version)
#      68     self._update_remote_server_config(self._url)
# ...

# %%
# !pip install moviepy SpeechRecognition language-tool-python
# Out:
# ...
#      ---------------------------------------- 0.0/388.3 kB ? eta -:--:--
#      --------------- ---------------------- 153.6/388.3 kB 4.6 MB/s eta 0:00:01
#      ------------------ ------------------- 184.3/388.3 kB 3.8 MB/s eta 0:00:01
#      ------------------ ------------------- 184.3/388.3 kB 3.8 MB/s eta 0:00:01
#      -------------------------- ----------- 266.2/388.3 kB 1.4 MB/s eta 0:00:01
#      -------------------------- ----------- 266.2/388.3 kB 1.4 MB/s eta 0:00:01
#      ------------------------------- ------ 317.4/388.3 kB 1.2 MB/s eta 0:00:01
#      ----------------------------------- -- 358.4/388.3 kB 1.2 MB/s eta 0:00:01
#      ----------------------------------- -- 358.4/388.3 kB 1.2 MB/s eta 0:00:01
#      ----------------------------------- -- 358.4/388.3 kB 1.2 MB/s eta 0:00:01
#      ----------------------------------- -- 358.4/388.3 kB 1.2 MB/s eta 0:00:01
#      ----------------------------------- -- 358.4/388.3 kB 1.2 MB/s eta 0:00:01
# ...

# %%
import speech_recognition as sr
import language_tool_python
from moviepy.editor import AudioFileClip

# Initialize recognizer and grammar tool
recognizer = sr.Recognizer()
tool = language_tool_python.LanguageTool('en-US')

def mp3_to_wav(mp3_file):
    """Convert MP3 file to WAV format using moviepy."""
    wav_file = mp3_file.replace('.mp3', '.wav')
    audio_clip = AudioFileClip(mp3_file)
    audio_clip.write_audiofile(wav_file, codec='pcm_s16le')
    return wav_file

def process_audio(audio_file):
    """Convert audio to text and check grammar."""
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)
        text = recognizer.recognize_google(audio_data)

    # Check grammar
    matches = tool.check(text)
    
    return text, matches

# Example usage
mp3_path = "question.mp3"  # Replace with your MP3 file path
wav_path = mp3_to_wav(mp3_path)
transcribed_text, grammar_issues = process_audio(wav_path)

# Output results
print("Transcribed Text:")
print(transcribed_text)
print("\nGrammar Issues:")
for issue in grammar_issues:
    print(f"Issue: {issue.message}, Context: {issue.context}, Correction: {issue.replacements}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       5 # Initialize recognizer and grammar tool
#       6 recognizer = sr.Recognizer()
# ----> 7 tool = language_tool_python.LanguageTool('en-US')
#       9 def mp3_to_wav(mp3_file):
#      10     """Convert MP3 file to WAV format using moviepy."""
#
# File ~\anaconda3\Lib\site-packages\language_tool_python\server.py:70, in LanguageTool.__init__(self, language, motherTongue, remote_server, newSpellings, new_spellings_persist, host, config, language_tool_download_version)
#      68     self._update_remote_server_config(self._url)
#      69 elif not self._server_is_alive():
# ---> 70     self._start_server_on_free_port()
#      71 if language is None:
#      72     try:
#
# File ~\anaconda3\Lib\site-packages\language_tool_python\server.py:270, in LanguageTool._start_server_on_free_port(self)
# ...

# %%
# !pip install grammar-check
# Out:
# ERROR: Could not find a version that satisfies the requirement grammar-check (from versions: none)
# ERROR: No matching distribution found for grammar-check

# %%
import speech_recognition as sr
from moviepy.editor import AudioFileClip
import grammar_check

# Initialize recognizer and grammar tool
recognizer = sr.Recognizer()
tool = grammar_check.LanguageTool('en-US')

def mp3_to_wav(mp3_file):
    """Convert MP3 file to WAV format using moviepy."""
    wav_file = mp3_file.replace('.mp3', '.wav')
    audio_clip = AudioFileClip(mp3_file)
    audio_clip.write_audiofile(wav_file, codec='pcm_s16le')
    return wav_file

def process_audio(audio_file):
    """Convert audio to text and check grammar."""
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)
        text = recognizer.recognize_google(audio_data)

    # Check grammar
    matches = tool.check(text)
    
    return text, matches

# Example usage
mp3_path = "path_to_your_audio_file.mp3"  # Replace with your MP3 file path
wav_path = mp3_to_wav(mp3_path)
transcribed_text, grammar_issues = process_audio(wav_path)

# Output results
print("Transcribed Text:")
print(transcribed_text)
print("\nGrammar Issues:")
for issue in grammar_issues:
    print(f"Issue: {issue['message']}, Context: {issue['context']}, Suggestions: {issue['replacements']}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 import speech_recognition as sr
#       2 from moviepy.editor import AudioFileClip
# ----> 3 import grammar_check
#       5 # Initialize recognizer and grammar tool
#       6 recognizer = sr.Recognizer()
#
# ModuleNotFoundError: No module named 'grammar_check'

# %%
# !pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    - -------------------------------------- 30.7/626.3 kB 1.3 MB/s eta 0:00:01
#    - -------------------------------------- 30.7/626.3 kB 1.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 81.9/626.3 kB 1.1 MB/s eta 0:00:01
#    ------- ------------------------------ 122.9/626.3 kB 798.9 kB/s eta 0:00:01
#    ----------- -------------------------- 194.6/626.3 kB 980.4 kB/s eta 0:00:01
#    --------------- ------------------------ 245.8/626.3 kB 1.1 MB/s eta 0:00:01
#    ----------------- -------------------- 286.7/626.3 kB 980.4 kB/s eta 0:00:01
#    -------------------- ------------------- 327.7/626.3 kB 1.0 MB/s eta 0:00:01
#    --------------------- ---------------- 358.4/626.3 kB 890.4 kB/s eta 0:00:01
#    --------------------- ---------------- 358.4/626.3 kB 890.4 kB/s eta 0:00:01
# ...

# %%
import speech_recognition as sr
from moviepy.editor import AudioFileClip
from textblob import TextBlob

# Initialize recognizer
recognizer = sr.Recognizer()

def mp3_to_wav(mp3_file):
    """Convert MP3 file to WAV format using moviepy."""
    wav_file = mp3_file.replace('.mp3', '.wav')
    audio_clip = AudioFileClip(mp3_file)
    audio_clip.write_audiofile(wav_file, codec='pcm_s16le')
    return wav_file

def process_audio(audio_file):
    """Convert audio to text and check grammar."""
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)
        text = recognizer.recognize_google(audio_data)

    # Check grammar using TextBlob
    blob = TextBlob(text)
    corrected_text = str(blob.correct())

    return text, corrected_text

# Example usage
mp3_path = "question1.mp3"  # Replace with your MP3 file path
wav_path = mp3_to_wav(mp3_path)
transcribed_text, corrected_text = process_audio(wav_path)

# Output results
print("Transcribed Text:")
print(transcribed_text)
print("\nCorrected Text:")
print(corrected_text)
# Out:
# MoviePy - Writing audio in question1.wav
# MoviePy - Done.
# Transcribed Text:
# what are your greatest strengths
#
# Corrected Text:
# what are your greatest strength
